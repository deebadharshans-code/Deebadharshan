# %% [markdown]
# <a href="https://colab.research.google.com/github/deebadharshans-code/Deebadharshan/blob/main/Unit1_PythonBasics/CE541E08_U1_Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CE541E08 — Introduction to Python and MATLAB Programming
# ## Unit 1 · Day 3 — Variables and Assignment Statements
#
# ---
#
# | | |
# |---|---|
# | **Course** | CE541E08 |
# | **Department** | Civil Engineering · Christ University |
# | **Instructor** | Dr. Arpan Pradhan |
# | **Unit** | Unit 1 |
# | **Session** | Day 3 |
# | **CO** | CO1 |
# | **Topics today** | Variable naming · naming conventions · multiple assignment · augmented assignment · Rational Method |
#
# ---
# > Run each grey code cell with **Shift + Enter**. Read the explanation above each cell first.
# > Instructor notes are marked `─── INSTRUCTOR NOTE ───`.
# ---

# %%
# STUDENT HEADER — fill in before starting
student_name = "DEEBADHARSHAN.S"
roll_number  = "2460111"
github_repo  = "https://github.com/your-username/CE541E08-2026"
session      = "Day 3"
print("╔══════════════════════════════════════════╗")
print("║         CE541E08 — Student Record         ║")
print("╠══════════════════════════════════════════╣")
print(f"║  Name    : {student_name:<31}║")
print(f"║  Roll    : {roll_number:<31}║")
print(f"║  Session : {session:<31}║")
print("╚══════════════════════════════════════════╝")
# Out:
# ╔══════════════════════════════════════════╗
# ║         CE541E08 — Student Record         ║
# ╠══════════════════════════════════════════╣
# ║  Name    : DEEBADHARSHAN.S                ║
# ║  Roll    : 2460111                        ║
# ║  Session : Day 3                          ║
# ╚══════════════════════════════════════════╝

# %% [markdown]
# ## Section 1 — Variables: named containers
#
# `pipe_diameter = 0.3` means: *store 0.3 in a container labelled pipe_diameter.*
# The `=` is **assignment**, not equality.
#
# **Good naming convention for engineering:**
# | ❌ Bad | ✅ Good |
# |---|---|
# | `d` | `pipe_diameter` |
# | `n` | `manning_n` |
# | `q` | `discharge_m3s` |
# | `x1` | `rainfall_mm` |

# %% [markdown]
# ### ▶ Cell 1 — Creating and updating variables

# %%
pipe_diameter = 0.3
print("Initial:", pipe_diameter, "m")

pipe_diameter = 0.6           # update — old value gone
print("Updated:", pipe_diameter, "m")

import math
area = math.pi * (pipe_diameter/2)**2
print("Area for new diameter:", round(area,4), "m²")

# ─── INSTRUCTOR NOTE ───────────────────────────────────────────
# Ask: "In Excel, what is the equivalent of a variable?"
# Answer: a named cell — same idea, different syntax.
# ───────────────────────────────────────────────────────────────

# %% [markdown]
# ### ▶ Cell 2 — Engineering variable naming in Manning's equation

# %%
import math

# Well-named variables — self-documenting code
pipe_diameter_m   = 0.3
manning_n         = 0.013
bed_slope         = 0.001

pipe_radius_m     = pipe_diameter_m / 2
flow_area_m2      = math.pi * pipe_radius_m**2
wetted_perim_m    = math.pi * pipe_diameter_m
hydraulic_rad_m   = flow_area_m2 / wetted_perim_m

velocity_ms       = (1/manning_n) * hydraulic_rad_m**(2/3) * bed_slope**0.5
discharge_m3s     = velocity_ms * flow_area_m2
discharge_lps     = discharge_m3s * 1000

print(f"Velocity   V = {velocity_ms:.3f} m/s")
print(f"Discharge  Q = {discharge_m3s:.5f} m³/s")
print(f"           Q = {discharge_lps:.2f} litres/s")

# ─── INSTRUCTOR NOTE ───────────────────────────────────────────
# Units in variable names (_m, _m2, _ms) prevent unit errors.
# A common engineering mistake: confusing m with mm.
# ───────────────────────────────────────────────────────────────

# %% [markdown]
# ### ▶ Cell 3 — Multiple assignment patterns

# %%
# Assign multiple variables on one line
width, depth, slope = 2.0, 0.8, 0.002
print(f"Width={width}m, Depth={depth}m, Slope={slope}")

# Swap two values without a temporary variable
upstream   = 105.4
downstream = 103.1
print(f"Before: up={upstream}, down={downstream}")
upstream, downstream = downstream, upstream
print(f"After:  up={upstream}, down={downstream}")

# Check types
print(f"
type(width)     = {type(width).__name__}")
print(f"type('concrete')= {type('concrete').__name__}")
print(f"type(True)      = {type(True).__name__}")

# %% [markdown]
# ### ▶ Cell 4 — Augmented assignment: accumulating rainfall

# %%
daily_rainfall = [12.4, 0.0, 35.6, 22.1, 8.9, 0.0, 41.2]
cumulative = 0.0

print(f"{'Day':<5} {'Daily (mm)':<14} {'Cumulative (mm)'}")
print("-" * 36)
for i, rain in enumerate(daily_rainfall, 1):
    cumulative += rain          # same as: cumulative = cumulative + rain
    print(f"{i:<5} {rain:<14.1f} {cumulative:.1f}")

print(f"
Weekly total: {cumulative:.1f} mm")

# ─── INSTRUCTOR NOTE ───────────────────────────────────────────
# += is the key pattern for running totals.
# Students will use this in Unit 2 for monthly rainfall sums.
# ───────────────────────────────────────────────────────────────

# %% [markdown]
# ---
# ## Day 3 Assignment — Rational Method
#
# Three sub-catchments: residential 12.5 ha C=0.65, commercial 4.2 ha C=0.85, parkland 8.0 ha C=0.30. Design intensity i=45 mm/hr.
# Compute: total area (ha and m²), weighted C, peak discharge Q (m³/s and L/s).
# *(Q = C·i·A where i in m/s, A in m²)*
# *(Answers: total=24.7 ha, C_w=0.5825, Q=0.01797 m³/s = 17.97 L/s)*

# %% [markdown]
# ### ▶ Assignment cell

# %%
# Rational Method — composite catchment
area_res_ha = ???;  c_res = ???
area_com_ha = ???;  c_com = ???
area_par_ha = ???;  c_par = ???
intensity_mmhr = 45.0

total_ha   = ???
total_m2   = ???
C_weighted = ???          # sum(Ci*Ai) / total_ha
intensity_ms = ???        # mm/hr → m/s: divide by 1000 then 3600
Q_m3s = ???

print(f"Total area   : {total_ha} ha  ({total_m2:.0f} m²)")
print(f"Weighted C   : {C_weighted:.3f}")
print(f"Q            : {Q_m3s:.5f} m³/s  ({Q_m3s*1000:.2f} L/s)")

# %% [markdown]
# ---
# ## Before next session — checklist
# - [ ] Completed all assignment cells
# - [ ] Saved notebook to Google Drive
# - [ ] Uploaded to GitHub: `Unit1_PythonBasics/CE541E08_U1_Day3.ipynb`
# - [ ] Commit message: `Day 3 assignment completed`
#
# ---
# *CE541E08 · Civil Engineering · Christ University · 2026–27 · Dr. Arpan Pradhan · arpan.pradhan@christuniversity.in*
